# %% [markdown]
# Importer les données

# %%
import pandas as pd

# Charger les données
df = pd.read_csv("C:\\Users\\lyna_\\Desktop\\Projet GIT\\Prédiction retard de vol\\data\\raw\\flight_delays_US.csv")

# Aperçu rapide
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    year  month carrier        carrier_name airport  \
# 0  2025      7      YV  Mesa Airlines Inc.     BWI
# 1  2025      7      YV  Mesa Airlines Inc.     CHS
# 2  2025      7      YV  Mesa Airlines Inc.     CLE
# 3  2025      7      YV  Mesa Airlines Inc.     CLT
# 4  2025      7      YV  Mesa Airlines Inc.     CMH
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Baltimore, MD: Baltimore/Washington Internatio...         18.0        2.0
# 1       Charleston, SC: Charleston AFB/International         48.0       16.0
# 2     Cleveland, OH: Cleveland-Hopkins International         65.0       10.0
# 3     Charlotte, NC: Charlotte Douglas International        134.0       31.0
# 4    Columbus, OH: John Glenn Columbus International         61.0       12.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        1.43        0.00  ...          0.0              0.00            0.0
# ...

# %% [markdown]
# Gérer les valeurs manquantes

# %%
# Vérifier les colonnes avec NaN
print(df.isna().sum())
df = df.dropna(subset=['arr_del15'])
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64
